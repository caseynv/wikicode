# %%
#import all the needed packages
import pywikibot

# Connect to enwiki
enwiki = pywikibot.Site('en', 'wikipedia')

# and then to wikidata
enwiki_repo = enwiki.data_repository()

#login to your wikidata page
pywikibot.Site().login()

# %%
#add text to a wikipedia/wikidata page


site = pywikibot.Site('wikidata', 'wikidata')
repo = site.data_repository()
page = pywikibot.Page(site, 'User:Caseynv/Outreachy_1')

def print_page(page):
    text = page.get()
    print(text)
        
print_page(page)
# Out:
# ==Article 1==
#
# {{Q|Q56603084}}
#
# * The first author is 'J.W Henning', and is defined as a string
#
# * The second author is 'J.T Sayre', and is defined as a string
#
# * The sixtieth author is 'Carole Tucker', has an alias of C. Tucker and is defined as a wikidata Item
# {{Q|Q56554628}} has {{P|P735}}=Carole and {{P|P734}}=Tucker
#
# * The sixty-first author is 'Keith Vanderlinde', has aliases of K. Vanderlinde, Keith W. Vanderlinde etc. and is defined as a wikidata Item
# {{Q|Q104918685}} has given name {{P|P734}}=Keith and {{P|P734}}=Vanderline
#
# * The thirteenth author is 'Hsin Chiang', has aliases of H. C. Chiang, HC Chiang etc. and is defined as a wikidata Item
# {{Q|Q87189799}} has no {{P|P735}}=Hsin and {{P|P734}}=Chiang
#
# * The fiftieth author is 'Valentyn Novosad', has no alias and is defined as a wikidata Item
# {{Q|Q87780526}} has {{P|P735}}=Valentyn and {{P|P734}}=Novosad
#
# * The fourth author is 'Peter A. R. Ade', has aliases of P. A. R. Ade, P. Ade etc. and is defined as a wikidata Item
# {{Q|Q53986456}} has {{P|P735}}=P. and {{P|P734}}=Ade
#
# ==Article 2==
#
# {{Q|Q56603083}}
#
# * The first author is 'A. Manzotti', and is defined as a string
#
# * The second author is 'K. T. Story', and is defined as a string
#
# * The third author is 'W. L. K. Wu', and is defined as a string
#
# * The twentieth author is 'Scott Dodelson', has no aliase and is defined as a wikidata Item
# {{Q|Q3476200}} has no {{P|P735}}=Scott and {{P|P734}}=Dodelson
#
# * The fifty-seventh author is 'Keith Vanderlinde', has aliases of K. Vanderlinde, Keith W. Vanderlinde etc. and is defined as a wikidata Item
# {{Q|Q104918685}} has {{P|P735}}=Keith and {{P|P734}}=Vanderlinde
#
# * The twelfth author is 'Hsin Chiang', has an aliases of H. C. Chiang, HC Chiang etc. and is defined as a wikidata Item
# {{Q|Q87189799}} has no {{P|P735}}=Hsin and {{P|P734}}=Chiang
#
# ==Article 3==
#
# {{Q|Q27450617}}
#
# The first author is 'Uroš Seljak', has no alias and is defined as a wikidata Item
# * {{Q|Q7901082}} has no {{P|P735}}=Uroš and {{P|P734}}=Seljak
#
# The second author is 'Matias Zaldarriaga', has no alias and is defined as a wikidata Item
# * {{Q|Q1383655}} has {{P|P735}}=Matias and {{P|P734}}=Zaldarriaga
#
# ==Article 4==
#
# {{Q|Q56603082}}
#
# * The first author is 'K. T. Story', and is defined as a string
#
# * The second author is 'C. L. Reichardt', and is defined as a string
#
# * The third author is 'Z. Hou', and is defined as a string
#
# * The fourth author is 'R. Keisler', and is defined as a string
#
# * The author is 'Kenneth Aird', has an alias of K. Aird and is defined as a wikidata Item
# {{Q|Q60171472}} has {{P|P735}}=Kenneth and {{P|P734}}=Aird
#
# * The forty-seventh author is 'Keith Vanderlinde', has aliases Keith W. Vanderlinde, Keith W Vanderlinde, K. W. Vanderlinde etc and is defined as a wikidata Item
# {{Q|Q104918685}} has {{P|P735}}=Keith and {{P|P734}}=Vanderlinde
#
# ==Article 5==
#
# {{Q|Q56603077}}
#
# * The first author is 'F. W. High', and is defined as a string
#
# * The second author is 'B. Stalder', and is defined as a string
#
# * The third author is 'J. Song', and is defined as a string
#
# * The forty-first author is 'Daniel P. Marrone', has alias Daniel Patrick Marrone, Daniel P Marrone, and Daniel Marrone and is defined as a wikidata Item
# {{Q|Q54237735}} has no {{P|P735}}=Daniel and {{P|P734}}=Marrone
#
# * The twenty-eighth author is 'Mario Hamuy', has an alias of Mario Hamuy Wackenhut and is defined as a wikidata Item
# {{Q|Q6764718}} has {{P|P735}}=Mario and {{P|P734}}=Hamuy
#
# * The author is 'Kenneth Aird', has an alias of K. Aird and is defined as a wikidata Item
# {{Q|Q60171472}} has no {{P|P735}}=Keith and {{P|P734}}=Aird
#
# * The sixty-fifth author is 'Keith Vanderlinde', has aliases of K. Vanderlinde, K Vanderlinde, Keith W. Vanderlinde etc and is defined as a wikidata Item
# {{Q|Q104918685}} has {{P|P735}}=Keith and {{P|P734}}=Vanderlinde
#
# * The fourth author is 'Peter A. R. Ade', has aliases of P. Ade, Peter A R Ade, P A R Ade etc and is defined as a wikidata Item
# {{Q|Q53986456} has no {{P|P735}}=Peter and P and {{P|P734}}=Ade
#
# * The sixty-third author is 'Christoper Stubbs', has aliases of Christopher William Stubbs, Christopher W Stubbs, C Stubbs etc and is defined as a wikidata Item
# {{Q|Q1086984}} has {{P|P735}}=Christopher and William and {{P|P734}}=Stubbs
#
# * The fifty-third author is 'Armin Rest', has no alias and is defined as a wikidata Item
# {{Q|Q110140950}} has {{P|P735}}=Armin and {{P|P734}}=Rest
#
#
#   Hello
#   Hello

# %%
#add text to a wikipedia/wikidata page


site = pywikibot.Site('wikidata', 'wikidata')
repo = site.data_repository()
page = pywikibot.Page(site, 'User:Caseynv/Outreachy_1')

def edit(page):
    text = page.get()
    text = text + "\n  Hello"
    page.text = text
    try:
        page.save()
        return 'Saved! Thank you!'
    except:
        return "Oops! Try again"
        
        
test = edit(page)
print(test)
# Out:
#  Saved! Thank you!
# Page [[wikidata:User:Caseynv/Outreachy 1]] saved

# %%
#print the qualifier and author names, given name, and family name.

def print_author_info(list_item):
    site = pywikibot.Site("wikidata", "wikidata")
    repo = site.data_repository()
    for data_item in list_item:
        item = pywikibot.ItemPage(repo, data_item) 
        item_dict = item.get()
    
        for claim in item_dict['claims']: # Loop through items
            if claim == 'P50':
                for source in item.claims[claim]:
                    QID = source.target.getID()
                
                    item1 = pywikibot.ItemPage(repo, QID) 
                    item_dict1 = item1.get()
                    print(item_dict1['labels']['en'])
                    print(item_dict1['descriptions']['en'])
                    try:
                        print(item_dict1['aliases']['en'])
                    except:
                        print('No description')
                    try:
                        item_new = item_dict1['claims']['P735']
                        for item1_new in item_new:
                            itemm = item1_new.target.getID()
                            QID1 = pywikibot.ItemPage(repo, itemm) 
                            name = QID1.get()
                            print('Given name: ' + name['labels']['en'])
                    except:
                        print('No Given name')
                    try:
                        item_new1 = item_dict1['claims']['P734']
                        for item1_new1 in item_new1:
                            itemm1 = item1_new1.target.getID()
                            QID2 = pywikibot.ItemPage(repo, itemm1) 
                            name1 = QID2.get()
                            print('Family name: ' + name1['labels']['en'])
                    except:
                        print('No Family name')
                    tt = list(source.qualifiers.items())
                    try:
                        for key, value in tt:
                            try:
                                if key == 'P1545':
                                    print('series ordinal: ' + value[0].getTarget())
                                
                            except:
                                print('No P1545')
                            try:
                                if key == 'P1932':
                                    print('stated as: ' + value[0].getTarget())
                                
                            except:
                                print('No P1932')
                    except:
                        print('No qualifiers')
                    
print_author_info(['Q56603083', 'Q56603084', 'Q27450617', 'Q56942987', "Q27450018"])

# %%
#print the qualifier and author names for author name string.

 
def print_authorstring_info(list_item):
    site = pywikibot.Site("wikidata", "wikidata")
    repo = site.data_repository()
    for data_item in list_item:
        item = pywikibot.ItemPage(repo, data_item) 
        item_dict = item.get()
    
        for claim in item_dict['claims']: # Loop through items
            if claim == 'P2093':
                try:
                    for source in item.claims[claim]:
                        QID = source.target
                        print(QID)
                        stat = list(source.qualifiers.items())
                    
                        try:
                            for key, value in stat:
                                print('series ordinal: ' + value[0].getTarget())
                        except:
                            print('No qualifier')
                except:
                    print('No author string')
                
print_authorstring_info(['Q56603083', 'Q56603084', 'Q27450617', 'Q56942987', "Q27450018"])
