# %%
import pywikibot
# Indent allows to indent multi-line strings

# Connect to enwiki
enwiki = pywikibot.Site('en', 'wikipedia')
# and then to wikidata
enwiki_repo = enwiki.data_repository()

#login to your wikidata page
pywikibot.Site().login()

# %%
#TODOS: Label the functions appropriately
#add text to a wikipedia/wikidata page

import pywikibot

site = pywikibot.Site('wikidata', 'wikidata')
repo = site.data_repository()
page = pywikibot.Page(site, 'User:Caseynv/Outreachy_1')

def deets(page):

    text = page.get()
    
    print(text)
        
test = deets(page)
print(test)
# Out:
# ==Article 1==
#
# {{Q|Q56603084}}
#
# The first author is 'Carole Tucker', has an alias of C. Tucker and is defined as a wikidata Item
# * {{Q|Q56554628}} has {{P|P735}}=Carole and {{P|P734}}=Tucker
#
# The second author is 'Keith Vanderlinde', has aliases of K. Vanderlinde, Keith W. Vanderlinde etc. and is defined as a wikidata Item
# * {{Q|Q104918685}} has given name {{P|P734}}=Keith and {{P|P734}}=Vanderline
#
# The third author is 'Hsin Chiang', has aliases of H. C. Chiang, HC Chiang etc. and is defined as a wikidata Item
# * {{Q|Q87189799}} has no {{P|P735}}=Hsin and {{P|P734}}=Chiang
#
# The fourth author is 'Valentyn Novosad', has no alias and is defined as a wikidata Item
# * {{Q|Q87780526}} has {{P|P735}}=Valentyn and {{P|P734}}=Novosad
#
# The third author is 'Peter A. R. Ade', has aliases of P. A. R. Ade, P. Ade etc. and is defined as a wikidata Item
# * {{Q|Q53986456}} has {{P|P735}}=P. and {{P|P734}}=Ade
#
# ==Article 2==
#
# {{Q|Q56603083}}
#
# ...

# %%
import pywikibot

#print out all the properties in the wikidata item
site = pywikibot.Site("wikidata", "wikidata")
repo = site.data_repository()
item = pywikibot.ItemPage(repo, "Q4115189")
def print_props():
    item_dict = item.get() #Get the item dictionary
    print(item_dict['labels']['en'])
    print(item_dict['aliases']['en'])
    clm_dict = item_dict["claims"] # Get the claim dictionary
    for clm in clm_dict:
        print(clm)
        print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')

print_props()
# Out:
# Wikidata Sandbox
# ['SB', 'Wikidata BOX', 'test', 'Wikidata SandboxItem', 'sandbox', 'Property test']
# P460
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P31
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P17
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P576
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P4565
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P36
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P150
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# P2048
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#print all the values of wikidata item in p50

import pywikibot
# Indent allows to indent multi-line strings



site = pywikibot.Site("wikidata", "wikidata")
repo = site.data_repository()
item = pywikibot.ItemPage(repo, "Q27450018")


item.get() #Fetch all page data, and cache it.

def print_values():
    claim = pywikibot.Claim(repo, u'P50')

    for claim in item.claims['P50']: #Finds all statements (P131):
        p_value = claim.getTarget()
        p_item_dict = p_value.get()
        print(p_value.title())
        print('\n*****************\n')
  
print_values()
# Out:
# Q53986456
#
# *****************
#
# Q60171472
#
# *****************
#
# Q84700165
#
# *****************
#
# Q60192273
#
# *****************
#
# Q59703000
#
# *****************
#
# Q56554628
#
# *****************
#
# Q104918685
#
# *****************
#
# Q87189799
#
# *****************

# %%
import pywikibot

#print wikidata item property(P50), corresponding values and properties for their authors
site = pywikibot.Site("wikidata", "wikidata")
repo = site.data_repository()
item = pywikibot.ItemPage(repo, "Q27450018")

def print_props_values(prop):
    item_dict = item.get()
    #Get the item dictionary
    clm_dict = item_dict["claims"] # Get the claim dictionary
    for clm in clm_dict:
        if 'P50' in clm:
            claim = pywikibot.Claim(repo, prop)
            for claim in item.claims[prop]: #Finds all statements (P131):
                p_value = claim.getTarget()
                p_item_dict = p_value.get()
                print(p_value.title())
            
                item1 = pywikibot.ItemPage(repo, p_value.title())
                item_dict1 = item1.get()
                #Get the item dictionary
                clm_dict1 = item_dict1["claims"] # Get the claim dictionary
                for clm1 in clm_dict1:
                    print(clm1)
                    print('\n*****************\n')
                    
print_props_values('P50')
# Out:
# Q53986456
# P496
#
# *****************
#
# P31
#
# *****************
#
# P106
#
# *****************
#
# P734
#
# *****************
#
# P735
#
# *****************
#
# P214
#
# *****************
#
# P7859
#
# *****************
#
# P21
#
# *****************
#
# P166
#
# *****************
#
# P1889
#
# *****************
#
# P2930
#
# *****************
#
# P6178
#
# *****************
#
# P27
#
# *****************
#
# P1412
#
# *****************
#
# P108
#
# *****************
#
# Q60171472
# P496
#
# *****************
#
# P31
#
# *****************
#
# P1153
#
# *****************
#
# P108
#
# *****************
#
# P106
#
# *****************
#
# P735
#
# *****************
#
# P2888
#
# *****************
#
# P6178
#
# *****************
#
# P734
#
# *****************
#
# P21
#
# *****************
#
# Q84700165
# P496
#
# *****************
#
# P31
#
# *****************
#
# P106
#
# *****************
#
# P735
#
# *****************
#
# P108
#
# *****************
#
# Q60192273
# P496
#
# ...

# %%
#TODOS: Label the functions appropriately
#add text to a wikipedia/wikidata page

import pywikibot

site = pywikibot.Site('wikidata', 'wikidata')
repo = site.data_repository()
page = pywikibot.Page(site, 'User:Caseynv/Outreachy_1')

def edit(page):

    text = page.get()
    
    text = text + "\n  Hello"
    
    page.text = text
             
    try:
        page.save()
        return ('\n Saved! Thank you!')
    except:
        print("Oops! Try again")
        return 0
        
test = edit(page)
print(test)
# Out:
#  Saved! Thank you!
# Page [[wikidata:User:Caseynv/Outreachy 1]] saved

# %%
#Family name of authors

import pywikibot

site = pywikibot.Site("wikidata", "wikidata")
repo = site.data_repository()
item = pywikibot.ItemPage(repo, 'Q27450018')

def author_family_name(sourcesid, famid, givid):
    
    # item.claims['P1343'][1].qualifiers.items():   
    # This are direct way to get list qualifiers. But '[1]' is hard link to index of list, it will break over time.
    
    for source in item.claims[sourcesid]:
        lis = source.target.id
        item1 = pywikibot.ItemPage(repo, lis)

        dict_ = item1.get()

        name = dict_['labels']['en']

        desc = dict_["descriptions"]["en"]
    
        dec = dict_["aliases"]["en"]

        try:
     
            for claim in dict_['claims'][famid]:
                lis1 = claim.getTarget().id
            
                item11 = pywikibot.ItemPage(repo, lis1)
                new = item11.id
                item2 = pywikibot.ItemPage(repo, new)

                dic = item2.get()
                nam = dic['labels']['en']
            
                print('The family name ID of ' + name + ' is ' + new + ' and the family name is ' + nam + '\n')
            
                print("\n--------------------------------------------------\n")
        except:
            print('The given name ID of ' + name + ' is ' + new + ' and the Given name is not specified')

        
author_family_name('P50', 'P734', 'P735')
# Out:
# The family name ID of Peter A. R. Ade is Q16158532 and the family name is Ade
#
#
# --------------------------------------------------
#
# The family name ID of Kenneth Aird is Q408512 and the family name is Aird
#
#
# --------------------------------------------------
#
# The given name ID of Lindsey Bleem is Q408512 and the Given name is not specified
# The family name ID of Elizabeth M. George is Q1260558 and the family name is George
#
#
# --------------------------------------------------
#
# The family name ID of Christian Reichardt is Q37455452 and the family name is Reichardt
#
#
# --------------------------------------------------
#
# The family name ID of Carole Tucker is Q13418278 and the family name is Tucker
#
#
# --------------------------------------------------
#
# The family name ID of Keith Vanderlinde is Q37495217 and the family name is Vanderlinde
#
#
# --------------------------------------------------
#
# ...

# %%
#TODOS
#Try to merge it with the family name



import pywikibot

site = pywikibot.Site("wikidata", "wikidata")
repo = site.data_repository()
item = pywikibot.ItemPage(repo, 'Q27450018')

def author_given_name(sourcesid, famid, givid):

# item.claims['P1343'][1].qualifiers.items():   
# This are direct way to get list qualifiers. But '[1]' is hard link to index of list, it will break over time.


    for source in item.claims[sourcesid]:
        lis = source.target.id
        item1 = pywikibot.ItemPage(repo, lis)

        dict_ = item1.get()

        name = dict_['labels']['en']

        desc = dict_["descriptions"]["en"]
    
        dec = dict_["aliases"]["en"]
    
        print(dec)
    
        print("\n******************************************************************\n")

        try:
            print ('Name of author: ' + name)
            print(name + ' : ' + desc)

            for claim in dict_['claims'][givid]:
                lis1 = claim.getTarget().id
            
                item11 = pywikibot.ItemPage(repo, lis1)
                new = item11.id
                item2 = pywikibot.ItemPage(repo, new)

            dic = item2.get()
            nam = dic['labels']['en']
            
            print('The given name ID of ' + name + ' is ' + new + ' and the Given name is ' + nam)
            
    
            print("\n++++++++++++++++++++++++++++++++++++++++++++\n")
    except:
        print('The given name ID of ' + name +
              ' is ' + new + ' and the Given name is not specified')
        
author_given_name('P50', 'P734', 'P735')
# Out:
# ['P. Ade', 'Peter A R Ade', 'P A R Ade', 'Peter A.R. Ade', 'P.A.R. Ade', 'P. A. R. Ade', 'Peter Ade']
#
# ******************************************************************
#
# Name of author: Peter A. R. Ade
# Peter A. R. Ade : researcher
# The given name ID of Peter A. R. Ade is Q19803513 and the Given name is P.
#
# ++++++++++++++++++++++++++++++++++++++++++++
# WARNING: API error mwoauth-invalid-authorization-invalid-user: The authorization headers in your request are for a user that does not exist here
# The given name ID of Peter A. R. Ade is Q2793400 and the Given name is not specified
# ['K. Aird']
#
# ******************************************************************
#
# Name of author: Kenneth Aird
# Kenneth Aird : researcher ORCID ID = 0000-0003-1441-9518
# WARNING: API error mwoauth-invalid-authorization-invalid-user: The authorization headers in your request are for a user that does not exist here
# ...
